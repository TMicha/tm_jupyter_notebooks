# %% [markdown]
# Analyze a small, publicly available dataset using Python's NumPy or Pandas libraries.
# 1. Explore the data:
#
# Print the first few rows using data.head().
# Check the data types of each column using data.info().
# Get summary statistics (mean, median, standard deviation, etc.) using data.describe().

# %%
#Importing Libraries
import pandas as pd
import numpy as np

# %%
# Loading the Netflix DataSet via url link

url = "https://raw.githubusercontent.com/allenkong221/netflix-titles-dataset/main/netflix_titles.csv"
df = pd.read_csv(url)

# %%
# Data Exploration
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %% [markdown]
# Observations
# - There are 6234 records in the dataset
# - There are missing values in the director, cast and country columns
# - Most of the columns has a text datatype asides the show_id and release_year columns

# %%
df.describe() #This will only output results for numerical features/variables/columns
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %% [markdown]
# The most average release year is 2013

# %% [markdown]
# 2. Calculate basic statistics:
#
# Calculate the mean, median, mode, and standard deviation for each numerical feature.
# Calculate the correlation between different features using data.corr().

# %%
# re-confirm the numerial features
df.select_dtypes(include="number").columns
# Out:
# Index(['show_id', 'release_year'], dtype='object')

# %%
df.release_year.mean()
# Out:
# np.float64(2013.3593198588387)

# %%
df.release_year.median()
# Out:
# np.float64(2016.0)

# %%
df.release_year.mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %%
df.release_year.std()
# Out:
# np.float64(8.811620351521556)

# %%
df.corr(numeric_only=True)
# Out:
#                show_id  release_year
# show_id       1.000000      0.566577
# release_year  0.566577      1.000000

# %% [markdown]
#  Here, we can see that the correlation is 1 for release_year and there is no relevant numeric feature to compare this with.
#  Therefore, feature engineering is required for 'duration' so as to determine actual correlation.
#  This is outside this module's scope and will be revisited down the line.
